# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from underthesea import word_tokenize, pos_tag, sent_tokenize
import warnings
from gensim import corpora, models, similarities
import jieba
import re

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load data

# %%
products = pd.read_csv("Cung cap HV/Product_new.csv")
reviews = pd.read_csv("Cung cap HV/Review_new.csv")

# %%
products.head(2)
# Out:
#     item_id                                               name  \
# 0  48102821  Tai nghe Bluetooth Inpods 12 - Cảm biến vân ta...
# 1  52333193  Tai nghe bluetooth không dây F9 True wireless ...
#
#                                          description  rating   price  \
# 0  THÔNG TIN CHI TIẾT\nDung lượng pin 300\nThời g...     4.0   77000
# 1  THÔNG TIN CHI TIẾT\nDung lượng pin 2000mah\nTh...     4.5  132000
#
#    list_price brand                                              group  \
# 0      300000   OEM  Thiết Bị Số - Phụ Kiện Số/Thiết Bị Âm Thanh và...
# 1      750000   OEM  Thiết Bị Số - Phụ Kiện Số/Thiết Bị Âm Thanh và...
#
#                                                  url  \
# 0  https://tai-nghe-bluetooth-inpods-12-cam-bien-...
# 1  https://tai-nghe-bluetooth-khong-day-f9-true-w...
#
#                                                image
# 0  https://salt.tikicdn.com/cache/280x280/ts/prod...
# 1  https://salt.tikicdn.com/cache/280x280/ts/prod...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4373 entries, 0 to 4372
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   item_id      4373 non-null   int64
#  1   name         4373 non-null   object
#  2   description  4370 non-null   object
#  3   rating       4373 non-null   float64
#  4   price        4373 non-null   int64
#  5   list_price   4373 non-null   int64
#  6   brand        4373 non-null   object
#  7   group        4373 non-null   object
#  8   url          4373 non-null   object
#  9   image        4373 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 341.8+ KB

# %%
products.shape
# Out:
# (4373, 10)

# %% [markdown]
# ### Data Transformation

# %%
products = products[products['name'].notnull()]

# %%
products['name_description'] = products.name + products.description

# %%
products = products[products['name_description'].notnull()]

# %%
products['name_desciption_pre'] = products['name_description'].apply(lambda x: word_tokenize(x,format='text'))

# %%
type(products)
# Out:
# pandas.core.frame.DataFrame

# %%
products.shape
# Out:
# (4370, 12)

# %% [markdown]
# ### Solution 2: Gensim

# %%
intro_products = [[text for text in x.split()] for x in products.name_desciption_pre]

# %%
len(intro_products)
# Out:
# 4370

# %%
intro_products[:1]
# Out:
# [['Tai_nghe',
#   'Bluetooth_Inpods',
#   '12',
#   '-',
#   'Cảm_biến',
#   'vân',
#   'tay',
#   ',',
#   'chống',
#   'nước',
#   ',',
#   'màu_sắc',
#   'đa_dạng',
#   '-',
#   '5',
#   'màu_sắc',
#   'lựa',
#   'chọnTHÔNG',
#   'TIN',
#   'CHI_TIẾT',
#   'Dung_lượng',
#   'pin',
#   '300',
#   'Thời_gian',
#   'pin',
#   '-',
#   'Thời_gian',
#   'nghe',
#   'nhạc',
#   'liên_tục',
#   'từ',
#   '2.5',
#   '-',
#   '4',
#   'h',
#   '-',
#   'Thời_gian',
#   'sạc',
#   'đầy',
#   'chỉ',
#   'khoảng',
#   '60',
#   'p',
#   '-',
#   'Thời_gian',
#   'chờ',
#   'lên',
#   'tới',
#   '140',
#   'giờ',
#   'Bluetooth',
#   '5',
#   'Thương_hiệu',
#   'OEM',
#   'Xuất_xứ',
#   'thương_hiệu',
#   'Trung_Quốc',
#   'Độ',
#   'nhạy_cảm_biến',
#   'vân',
#   'tay',
#   'Model',
#   'i12',
#   'Loại',
#   'Jack',
#   'cắm',
#   'USB_Cable',
#   'Trọng_lượng',
#   '300',
#   'g',
#   'Thời_gian',
#   'sử_dụng',
#   '-',
#   'Thời_gian',
#   'nghe',
#   'nhạc',
#   'liên_tục',
#   'từ',
#   '2.5',
#   '-',
#   '4',
#   'h',
#   'SKU',
#   '4096608751631',
#   'MÔ_TẢ',
#   'SẢN_PHẨM',
#   'INPOD_12',
#   'là',
#   'phiên_bản',
#   'nâng_cấp',
#   'mới',
#   'nhất',
#   ',',
#   'tai_nghe',
#   'Bluetooth_5.0',
#   'có',
#   'thiết_kế',
#   'tỉ_lệ',
#   'chuẩn',
#   '1',
#   ':',
#   '1',
#   'với',
#   'tai',
#   'Airpod',
#   'chính',
#   'hãng',
#   'Lược_bỏ',
#   'nút',
#   'bấm',
#   'trên',
#   'thân',
#   'tai',
#   'thay',
#   'vào',
#   'đó',
#   'là',
#   'nút',
#   'cảm_ứng',
#   'sử_dụng',
#   'dễ_dàng',
#   'và',
#   'thuận_tiện',
#   'hơn',
#   'Thao_tác',
#   'nhận',
#   'cuộc',
#   'gọi',
#   'đến',
#   ',',
#   'chuyển',
#   'nhạc',
#   '...',
#   'một_cách',
#   'dễ_dàng',
#   'chỉ',
#   'bằng',
#   '1',
#   'chạm',
#   'Bluetooth_5.0',
#   'mới',
#   'nhất',
#   'cho',
#   'kết_nối',
#   'vô_cùng',
#   'ổn_định',
#   '-',
#   'Bluetooth_5.0',
#   'mới',
#   'nhất',
#   'cho',
#   'kết_nối',
#   'vô_cùng',
#   'ổn_định',
#   '-',
#   '2',
#   'tai',
#   'nghe',
#   'tự',
#   'kết_nối',
#   'với',
#   'nhau',
#   'khi',
#   'được',
#   'lấy',
#   'ra',
#   'từ',
#   'dock',
#   'sạc',
#   '-',
#   'Chất',
#   'âm',
#   'và',
#   'thời_lượng',
#   'pin',
#   'được',
#   'cải_thiện',
#   'tối_ưu',
#   '-',
#   'Dock',
#   'sạc',
#   'tiện_lợi',
#   'cho',
#   'tới',
#   '4',
#   'lần',
#   'sạc',
#   'đầy',
#   'pin',
#   'tai_nghe',
#   '-',
#   'Các',
#   'thiết_bị',
#   'tương_thích',
#   ':',
#   'các',
#   'thiết_bị',
#   'Bluetooth',
#   'như',
#   'cho',
#   'Xiaomi',
#   ',',
#   'Samsung',
#   ',',
#   'Apple',
#   ',',
#   'Huawei',
#   ',',
#   'OPPO',
#   ',',
#   'vivo',
#   ',',
#   'Lenovo',
#   ',',
#   'tablet',
#   ',',
#   'v',
#   '._v',
#   '.',
#   '-',
#   'Thời_gian',
#   'nghe',
#   'nhạc',
#   'liên_tục',
#   'từ',
#   '2.5',
#   '-',
#   '4',
#   'h',
#   '-',
#   'Thời_gian',
#   'sạc',
#   'đầy',
#   'chỉ',
#   'khoảng',
#   '60',
#   'p',
#   '-',
#   'Thời_gian',
#   'chờ',
#   'lên',
#   'tới',
#   '140',
#   'giờ',
#   'Giá',
#   'sản_phẩm',
#   'trên',
#   'Tiki',
#   'đã',
#   'bao_gồm',
#   'thuế',
#   'theo',
#   'luật',
#   'hiện_hành',
#   '.',
#   'Tuy_nhiên',
#   'tuỳ',
#   'vào',
#   'từng',
#   'loại',
#   'sản_phẩm',
#   'hoặc',
#   'phương_thức',
#   ',',
#   'địa_chỉ',
#   'giao',
#   'hàng',
#   'mà',
#   'có_thể',
#   'phát_sinh',
#   'thêm',
#   'chi_phí',
#   'khác',
#   'như',
#   'phí',
#   'vận_chuyển',
#   ',',
#   'phụ_phí',
#   'hàng',
#   'cồng_kềnh',
#   ',',
#   '...']]

# %%
# remove ' ' element in texts
intro_products_re = [[t.lower() for t in text if not t in ['', ' ', ',', '.', '...', '-',':', ';', '?', '%', '(', ')', '+', '\d+','...']] for text in  intro_products]

# %%
intro_products_re[:1]
# Out:
# [['tai_nghe',
#   'bluetooth_inpods',
#   '12',
#   'cảm_biến',
#   'vân',
#   'tay',
#   'chống',
#   'nước',
#   'màu_sắc',
#   'đa_dạng',
#   '5',
#   'màu_sắc',
#   'lựa',
#   'chọnthông',
#   'tin',
#   'chi_tiết',
#   'dung_lượng',
#   'pin',
#   '300',
#   'thời_gian',
#   'pin',
#   'thời_gian',
#   'nghe',
#   'nhạc',
#   'liên_tục',
#   'từ',
#   '2.5',
#   '4',
#   'h',
#   'thời_gian',
#   'sạc',
#   'đầy',
#   'chỉ',
#   'khoảng',
#   '60',
#   'p',
#   'thời_gian',
#   'chờ',
#   'lên',
#   'tới',
#   '140',
#   'giờ',
#   'bluetooth',
#   '5',
#   'thương_hiệu',
#   'oem',
#   'xuất_xứ',
#   'thương_hiệu',
#   'trung_quốc',
#   'độ',
#   'nhạy_cảm_biến',
#   'vân',
#   'tay',
#   'model',
#   'i12',
#   'loại',
#   'jack',
#   'cắm',
#   'usb_cable',
#   'trọng_lượng',
#   '300',
#   'g',
#   'thời_gian',
#   'sử_dụng',
#   'thời_gian',
#   'nghe',
#   'nhạc',
#   'liên_tục',
#   'từ',
#   '2.5',
#   '4',
#   'h',
#   'sku',
#   '4096608751631',
#   'mô_tả',
#   'sản_phẩm',
#   'inpod_12',
#   'là',
#   'phiên_bản',
#   'nâng_cấp',
#   'mới',
#   'nhất',
#   'tai_nghe',
#   'bluetooth_5.0',
#   'có',
#   'thiết_kế',
#   'tỉ_lệ',
#   'chuẩn',
#   '1',
#   '1',
#   'với',
#   'tai',
#   'airpod',
#   'chính',
#   'hãng',
#   'lược_bỏ',
#   'nút',
#   'bấm',
#   'trên',
#   'thân',
#   'tai',
#   'thay',
#   'vào',
#   'đó',
#   'là',
#   'nút',
#   'cảm_ứng',
#   'sử_dụng',
#   'dễ_dàng',
#   'và',
#   'thuận_tiện',
#   'hơn',
#   'thao_tác',
#   'nhận',
#   'cuộc',
#   'gọi',
#   'đến',
#   'chuyển',
#   'nhạc',
#   'một_cách',
#   'dễ_dàng',
#   'chỉ',
#   'bằng',
#   '1',
#   'chạm',
#   'bluetooth_5.0',
#   'mới',
#   'nhất',
#   'cho',
#   'kết_nối',
#   'vô_cùng',
#   'ổn_định',
#   'bluetooth_5.0',
#   'mới',
#   'nhất',
#   'cho',
#   'kết_nối',
#   'vô_cùng',
#   'ổn_định',
#   '2',
#   'tai',
#   'nghe',
#   'tự',
#   'kết_nối',
#   'với',
#   'nhau',
#   'khi',
#   'được',
#   'lấy',
#   'ra',
#   'từ',
#   'dock',
#   'sạc',
#   'chất',
#   'âm',
#   'và',
#   'thời_lượng',
#   'pin',
#   'được',
#   'cải_thiện',
#   'tối_ưu',
#   'dock',
#   'sạc',
#   'tiện_lợi',
#   'cho',
#   'tới',
#   '4',
#   'lần',
#   'sạc',
#   'đầy',
#   'pin',
#   'tai_nghe',
#   'các',
#   'thiết_bị',
#   'tương_thích',
#   'các',
#   'thiết_bị',
#   'bluetooth',
#   'như',
#   'cho',
#   'xiaomi',
#   'samsung',
#   'apple',
#   'huawei',
#   'oppo',
#   'vivo',
#   'lenovo',
#   'tablet',
#   'v',
#   '._v',
#   'thời_gian',
#   'nghe',
#   'nhạc',
#   'liên_tục',
#   'từ',
#   '2.5',
#   '4',
#   'h',
#   'thời_gian',
#   'sạc',
#   'đầy',
#   'chỉ',
#   'khoảng',
#   '60',
#   'p',
#   'thời_gian',
#   'chờ',
#   'lên',
#   'tới',
#   '140',
#   'giờ',
#   'giá',
#   'sản_phẩm',
#   'trên',
#   'tiki',
#   'đã',
#   'bao_gồm',
#   'thuế',
#   'theo',
#   'luật',
#   'hiện_hành',
#   'tuy_nhiên',
#   'tuỳ',
#   'vào',
#   'từng',
#   'loại',
#   'sản_phẩm',
#   'hoặc',
#   'phương_thức',
#   'địa_chỉ',
#   'giao',
#   'hàng',
#   'mà',
#   'có_thể',
#   'phát_sinh',
#   'thêm',
#   'chi_phí',
#   'khác',
#   'như',
#   'phí',
#   'vận_chuyển',
#   'phụ_phí',
#   'hàng',
#   'cồng_kềnh']]

# %%
# Obtain the number of features based on dictionary: Use corpora.Dictionary
dictionary = corpora.Dictionary(intro_products_re)

# %%
# List of features in dictionary
dictionary.token2id
# Out:
# {'._v': 0,
#  '1': 1,
#  '12': 2,
#  '140': 3,
#  '2': 4,
#  '2.5': 5,
#  '300': 6,
#  '4': 7,
#  '4096608751631': 8,
#  '5': 9,
#  '60': 10,
#  'airpod': 11,
#  'apple': 12,
#  'bao_gồm': 13,
#  'bluetooth': 14,
#  'bluetooth_5.0': 15,
#  'bluetooth_inpods': 16,
#  'bấm': 17,
#  'bằng': 18,
#  'chi_phí': 19,
#  'chi_tiết': 20,
#  'cho': 21,
#  'chuyển': 22,
#  'chuẩn': 23,
#  'chính': 24,
#  'chạm': 25,
#  'chất': 26,
#  'chỉ': 27,
#  'chọnthông': 28,
#  'chống': 29,
#  'chờ': 30,
#  'cuộc': 31,
#  'các': 32,
#  'có': 33,
#  'có_thể': 34,
#  'cải_thiện': 35,
#  'cảm_biến': 36,
#  'cảm_ứng': 37,
#  'cắm': 38,
#  'cồng_kềnh': 39,
#  'dock': 40,
#  'dung_lượng': 41,
#  'dễ_dàng': 42,
#  'g': 43,
#  'giao': 44,
#  'giá': 45,
#  'giờ': 46,
#  'gọi': 47,
#  'h': 48,
#  'hiện_hành': 49,
#  'hoặc': 50,
#  'huawei': 51,
#  'hàng': 52,
#  'hãng': 53,
#  'hơn': 54,
#  'i12': 55,
#  'inpod_12': 56,
#  'jack': 57,
#  'khi': 58,
#  'khoảng': 59,
#  'khác': 60,
#  'kết_nối': 61,
#  'lenovo': 62,
#  'liên_tục': 63,
#  'loại': 64,
#  'luật': 65,
#  'là': 66,
#  'lên': 67,
#  'lược_bỏ': 68,
#  'lấy': 69,
#  'lần': 70,
#  'lựa': 71,
#  'model': 72,
#  'mà': 73,
#  'màu_sắc': 74,
#  'mô_tả': 75,
#  'một_cách': 76,
#  'mới': 77,
#  'nghe': 78,
#  'nhau': 79,
#  'như': 80,
#  'nhạc': 81,
#  'nhạy_cảm_biến': 82,
#  'nhất': 83,
#  'nhận': 84,
#  'nâng_cấp': 85,
#  'nút': 86,
#  'nước': 87,
#  'oem': 88,
#  'oppo': 89,
#  'p': 90,
#  'phiên_bản': 91,
#  'phát_sinh': 92,
#  'phí': 93,
#  'phương_thức': 94,
#  'phụ_phí': 95,
#  'pin': 96,
#  'ra': 97,
#  'samsung': 98,
#  'sku': 99,
#  'sạc': 100,
#  'sản_phẩm': 101,
#  'sử_dụng': 102,
#  'tablet': 103,
#  'tai': 104,
#  'tai_nghe': 105,
#  'tay': 106,
#  'thao_tác': 107,
#  'thay': 108,
#  'theo': 109,
#  'thiết_bị': 110,
#  'thiết_kế': 111,
#  'thuận_tiện': 112,
#  'thuế': 113,
#  'thân': 114,
#  'thêm': 115,
#  'thương_hiệu': 116,
#  'thời_gian': 117,
#  'thời_lượng': 118,
#  'tiki': 119,
#  'tin': 120,
#  'tiện_lợi': 121,
#  'trung_quốc': 122,
#  'trên': 123,
#  'trọng_lượng': 124,
#  'tuy_nhiên': 125,
#  'tuỳ': 126,
#  'tương_thích': 127,
#  'tỉ_lệ': 128,
#  'tối_ưu': 129,
#  'tới': 130,
#  'từ': 131,
#  'từng': 132,
#  'tự': 133,
#  'usb_cable': 134,
#  'v': 135,
#  'vivo': 136,
#  'và': 137,
#  'vào': 138,
#  'vân': 139,
#  'vô_cùng': 140,
#  'vận_chuyển': 141,
#  'với': 142,
#  'xiaomi': 143,
#  'xuất_xứ': 144,
#  'âm': 145,
#  'đa_dạng': 146,
#  'đã': 147,
#  'đó': 148,
#  'được': 149,
#  'đầy': 150,
#  'đến': 151,
#  'địa_chỉ': 152,
#  'độ': 153,
#  'ổn_định': 154,
#  '._giá': 155,
#  '._hai': 156,
#  '._không': 157,
#  '._nhấn': 158,
#  '._tai_nghe': 159,
#  '._trọng_lượng': 160,
#  '._tự': 161,
#  '._đặt': 162,
#  '._•': 163,
#  '/': 164,
#  '0': 165,
#  '10': 166,
#  '100': 167,
#  '120': 168,
#  '20': 169,
#  '2000': 170,
#  '25': 171,
#  '35': 172,
#  '50': 173,
#  '7319492804496': 174,
#  '90': 175,
#  'android': 176,
#  'bluetooth_f9_5.0': 177,
#  'bài': 178,
#  'báo': 179,
#  'bên': 180,
#  'bước': 181,
#  'bạn': 182,
#  'bật': 183,
#  'bỏ': 184,
#  'cao': 185,
#  'chip_bluetooth_5.0': 186,
#  'chất_lượng': 187,
#  'chế_độ': 188,
#  'chức_năng': 189,
#  'cvc_8.0': 190,
#  'cáp': 191,
#  'còn': 192,
#  'công_nghệ_khử': 193,
#  'cùng': 194,
#  'cả': 195,
#  'cảm_giác': 196,
#  'của': 197,
#  'dc': 198,
#  'dock_sạc': 199,
#  'dung': 200,
#  'dây': 201,
#  'f9': 202,
#  'f9_5.0': 203,
#  'f9_true': 204,
#  'giữ': 205,
#  'hiển_thị': 206,
#  'hoàn_toàn': 207,
#  'hoạt_động': 208,
#  'hz': 209,
#  'hát': 210,
#  'hướng_dẫn': 211,
#  'hệ': 212,
#  'hỗ_trợ': 213,
#  'hộp': 214,
#  'ios': 215,
#  'iphone': 216,
#  'khoảng_cách': 217,
#  'khít': 218,
#  'không': 219,
#  'khỏi': 220,
#  'khởi_động': 221,
#  'képthông': 222,
#  'kế': 223,
#  'led': 224,
#  'lúc': 225,
#  'lưu_ý': 226,
#  'lương': 227,
#  'lại': 228,
#  'lẻ': 229,
#  'm': 230,
#  'mah': 231,
#  'microusb': 232,
#  'mà_còn': 233,
#  'màn_hình': 234,
#  'mạnh_mẽ': 235,
#  'mỗi': 236,
#  'một': 237,
#  'mở': 238,
#  'next': 239,
#  'nguyên': 240,
#  'ngắt': 241,
#  'nhanh': 242,
#  'nhung': 243,
#  'nhấc': 244,
#  'nhấn': 245,
#  'nhấp_nháy': 246,
#  'nhẹ': 247,
#  'nó': 248,
#  'năng_lượng': 249,
#  'nối': 250,
#  'o': 251,
#  'pause': 252,
#  'phạm_vi': 253,
#  'qua': 254,
#  'reset': 255,
#  'riêng_lẻ': 256,
#  'rất': 257,
#  'rồi': 258,
#  's': 259,
#  'siri': 260,
#  'sẵn_sàng': 261,
#  'sẽ': 262,
#  'thai': 263,
#  'thoải_mái': 264,
#  'thì': 265,
#  'thấy': 266,
#  'thực_hiện': 267,
#  'tiêng': 268,
#  'tiếng': 269,
#  'tiết_kiệm': 270,
#  'trong': 271,
#  'trung_thực': 272,
#  'trường_hợp': 273,
#  'trạng': 274,
#  'trở_lại': 275,
#  'tên': 276,
#  'tìm': 277,
#  'tìm_kiếm': 278,
#  'tăng_giảm': 279,
#  'tần_số': 280,
#  'từ_chối': 281,
#  'tự_động': 282,
#  'v5': 283,
#  'vòng': 284,
#  'wireless': 285,
#  'xa': 286,
#  'xanh': 287,
#  'yếu': 288,
#  'âm_lượng': 289,
#  'âm_thanh': 290,
#  'đang': 291,
#  'điều_hành': 292,
#  'điện_thoại': 293,
#  'đàm_thoại': 294,
#  'đèn': 295,
#  'để': 296,
#  'đồng_thời': 297,
#  'độ_nhạy': 298,
#  'động': 299,
#  'ấn': 300,
#  'ồn': 301,
#  'ở': 302,
#  '–_đỏ': 303,
#  '•': 304,
#  '…': 305,
#  '._công_nghệ_chuột_quang': 306,
#  '._điều': 307,
#  '._độ': 308,
#  '1000': 309,
#  '1000dpi': 310,
#  '1000dpi_model_m331': 311,
#  '2.4_ghz': 312,
#  '24': 313,
#  '3': 314,
#  '3057399746627': 315,
#  'aa': 316,
#  'bo': 317,
#  'bàn': 318,
#  'bàn_tay': 319,
#  'bám': 320,
#  'bề_mặt': 321,
#  'bền': 322,
#  'bị': 323,
#  'bớt': 324,
#  'chuột': 325,
#  'chuột_quang': 326,
#  'chuộtlogitech': 327,
#  'cách': 328,
#  'công_nghệ': 329,
#  'công_việc': 330,
#  'cũng': 331,
#  'cơ_bản': 332,
#  'cần': 333,
#  'cần_thiết': 334,
#  'cổ_tay': 335,
#  'di_chuyển': 336,
#  'dpi': 337,
#  'dùng': 338,
#  'gián_đoạn': 339,
#  'giúp': 340,
#  'giải_trí': 341,
#  'giảm': 342,
#  'giữa_chừng': 343,
#  'gây': 344,
#  'gạt': 345,
#  'gần': 346,
#  'gắn': 347,
#  'gọn': 348,
#  'gồ_ghề': 349,
#  'hay': 350,
#  'hiệu': 351,
#  'hiệu_quả': 352,
#  'hiệu_suất': 353,
#  'hãngthông': 354,
#  'hãy': 355,
#  'hình_tam_giác': 356,
#  'hết': 357,
#  'học_tập': 358,
#  'hữu_ích': 359,
#  'khối': 360,
#  'kéo_dài': 361,
#  'kích_thước': 362,
#  'kề': 363,
#  'liền': 364,
#  'lo_lắng': 365,
#  'logitech_m331': 366,
#  'logitech_m331_silent': 367,
#  'logitech_độ': 368,
#  'làm_việc': 369,
#  'lâu': 370,
#  'lòng': 371,
#  'm331': 372,
#  'màu': 373,
#  'mã': 374,
#  'mình': 375,
#  'môi_trường': 376,
#  'mượt': 377,
#  'mượt_mà': 378,
#  'mắt': 379,
#  'mặt': 380,
#  'mỏi': 381,
#  'mờ': 382,
#  'nghĩa_là': 383,
#  'ngoài_ra': 384,
#  'nguồn': 385,
#  'ngón': 386,
#  'ngón_tay': 387,
#  'người': 388,
#  'nhiều': 389,
#  'nhỏ': 390,
#  'những': 391,
#  'này': 392,
#  'nữa': 393,
#  'of': 394,
#  'off': 395,
#  'on': 396,
#  'phân_giải': 397,
#  'phần': 398,
#  'quang': 399,
#  'quang_học': 400,
#  'quiet_mark': 401,
#  'quá_trình': 402,
#  'receiver': 403,
#  'sang_trọng': 404,
#  'sáng': 405,
#  'sát': 406,
#  'sản_phẩm_độ': 407,
#  'sắp_xếp': 408,
#  'sự': 409,
#  'tháng': 410,
#  'thương': 411,
#  'tiên_tiến': 412,
#  'tiêu_hao': 413,
#  'tiếng_động': 414,
#  'trang_bị': 415,
#  'tránh': 416,
#  'tròn': 417,
#  'trơn': 418,
#  'trượt': 419,
#  'tuổi_thọ': 420,
#  'tín_hiệu': 421,
#  'tăng': 422,
#  'tạo': 423,
#  'tối': 424,
#  'tốn': 425,
#  'usb': 426,
#  'uốn_lượn': 427,
#  'việc': 428,
#  'xung_quanh': 429,
#  'yên_lặng': 430,
#  'yêu_cầu': 431,
#  'ôm': 432,
#  'đau': 433,
#  'đem': 434,
#  'đêm': 435,
#  'đường_cong': 436,
#  'đảm_bảo': 437,
#  'đặc_biệt': 438,
#  'đục': 439,
#  'ảnh_hưởng': 440,
#  '._thương_hiệu': 441,
#  '10m_•_công_suất': 442,
#  '1200': 443,
#  '120h': 444,
#  '1500': 445,
#  '20kh': 446,
#  '248g': 447,
#  '3.7_v_•': 448,
#  '5.0': 449,
#  '5h': 450,
#  '5w_•': 451,
#  '6755510112852': 452,
#  '8': 453,
#  '80': 454,
#  '[': 455,
#  ']_]': 456,
#  'acome': 457,
#  'bluetooth_5.0_kiêm': 458,
#  'buetooth': 459,
#  'báo_thức': 460,
#  'chơi': 461,
#  'công_nghệ_bluetooth_5.0': 462,
#  'db': 463,
#  'dải_tần': 464,
#  'gương': 465,
#  'hồng': 466,
#  'indonesia': 467,
#  'kiêm': 468,
#  'kính': 469,
#  'kông': 470,
#  'led_•': 471,
#  'loa': 472,
#  'lớn': 473,
#  'màn': 474,
#  'ngắt_quãng': 475,
#  'nhiễu': 476,
#  'nhu_cầu': 477,
#  'nhưng': 478,
#  'nhớ': 479,
#  'phát': 480,
#  'phân_phối': 481,
#  'playtime': 482,
#  'ram': 483,
#  'robot': 484,
#  'tf._giá': 485,
#  'thông_minh': 486,
#  'thông_số': 487,
#  'thẻ': 488,
#  'tráng': 489,
#  'trình': 490,
#  'tình_trạng': 491,
#  'tính_năng': 492,
#  'tốc_độ': 493,
#  'tỷ_lệ': 494,
#  'z': 495,
#  'đáp_ứng': 496,
#  'đầu_ra': 497,
#  'đồng_hồ': 498,
#  'độc_quyền': 499,
#  '•_cố': 500,
#  '≥': 501,
#  ',_3': 502,
#  '._chíp_h1giúp': 503,
#  '._công_nghệ_adaptive_eq': 504,
#  '._cảm_biến': 505,
#  '._hơn_thế_nữa': 506,
#  '._hộp': 507,
#  '._một': 508,
#  '._việc': 509,
#  '100_%': 510,
#  '18': 511,
#  '200': 512,
#  '21.7': 513,
#  '21.8': 514,
#  '24.0': 515,
#  '3.5': 516,
#  '30.9': 517,
#  '4,5': 518,
#  '45,6': 519,
#  '45.2': 520,
#  '45.6': 521,
#  '5.4': 522,
#  '60.6': 523,
#  '8940002543605': 524,
#  'airpods': 525,
#  'airpods_pro': 526,
#  'apple_airpods_pro': 527,
#  'apple_watch': 528,
#  'ar': 529,
#  'athông': 530,
#  'bluetooth_apple_airpods_pro_true_wireless': 531,
#  'bên_cạnh': 532,
#  'bẩn': 533,
#  'bỏ_qua': 534,
#  'bổ_sung': 535,
#  'bộ': 536,
#  'bộ_khuếch_đại': 537,
#  'bụi': 538,
#  'chi': 539,
#  'chia_sẻ': 540,
#  'chip': 541,
#  'cho_phép': 542,
#  'chuyển_đổi': 543,
#  'chúng': 544,
#  'chắc': 545,
#  'chỉnh': 546,
#  'chống_ồn': 547,
#  'chủ_động': 548,
#  'cuối_cùng': 549,
#  'cách_âm': 550,
#  'công_nghệ_adaptive_eq': 551,
#  'cùng_với': 552,
#  'cũ': 553,
#  'cấp': 554,
#  'cổng': 555,
#  'cụ_thể': 556,
#  'dải': 557,
#  'dừng': 558,
#  'earbud': 559,
#  'giây': 560,
#  'gió': 561,
#  'giọng': 562,
#  'giữa': 563,
#  'gram': 564,
#  'h1': 565,
#  'hai': 566,
#  'hey_hey_siri': 567,
#  'hình_dạng': 568,
#  'hướng': 569,
#  'in-ear': 570,
#  'ipx4': 571,
#  'khung': 572,
#  'khuếch_đại': 573,
#  'khá': 574,
#  'khả_năng': 575,
#  'khử': 576,
#  'kiểm_soát': 577,
#  'kiểm_tra': 578,
#  'kết_hợp': 579,
#  'loại_bỏ': 580,
#  'làm': 581,
#  'lưu_trữ': 582,
#  'lưới': 583,
#  'lắng_nghe': 584,
#  'lực': 585,
#  'micro': 586,
#  'micrô': 587,
#  'mm': 588,
#  'model_mwp22': 589,
#  'mong_muốn': 590,
#  'mwp22': 591,
#  'méo': 592,
#  'mút': 593,
#  'mạnh': 594,
#  'mẫu': 595,
#  'mềm': 596,
#  'mọi': 597,
#  'mở_rộng': 598,
#  'mức_độ': 599,
#  'mỹ': 600,
#  'ngay': 601,
#  'ngay_lập_tức': 602,
#  'ngoài': 603,
#  'nhân': 604,
#  'nhờ': 605,
#  'nhựa': 606,
#  'nâng': 607,
#  'nét': 608,
#  'nói': 609,
#  'nói_chuyện': 610,
#  'nền': 611,
#  'phát_hiện': 612,
#  'phù_hợp': 613,
#  'podcast': 614,
#  'rõ': 615,
#  'rõ_ràng': 616,
#  'sau': 617,
#  'silicon': 618,
#  'suốt': 619,
#  'sẻ': 620,
#  'sống_động': 621,
#  'sở_hữu': 622,
#  'sở_hữu_tính_năng': 623,
#  'sức_khỏe': 624,
#  'sử': 625,
#  'thay_vì': 626,
#  'theo_dõi': 627,
#  'thuần_khiết': 628,
#  'thấp': 629,
#  'thế': 630,
#  'thời_trang': 631,
#  'tiêu_chuẩn': 632,
#  'tiếng_ồn': 633,
#  'toàn': 634,
#  'trong_trẻo': 635,
#  'trước': 636,
#  'trả_lời': 637,
#  'trầm': 638,
#  'trở_nên': 639,
#  'tái_tạo': 640,
#  'tình_huống': 641,
#  'tùy': 642,
#  'tương_tự': 643,
#  'tạm': 644,
#  'tần_suất': 645,
#  'tận_hưởng': 646,
#  'tối_đa': 647,
#  'tốt': 648,
#  'vn': 649,
#  'vượt_bậc': 650,
#  'vẫn': 651,
#  'vậy': 652,
#  'xảy': 653,
#  'xử_lý': 654,
#  'âm_nhạc': 655,
#  'điều_chỉnh': 656,
#  'điều_khiển': 657,
#  'điểu': 658,
#  'điện_năng': 659,
#  'đơn_giản': 660,
#  'ấn_tượng': 661,
#  '–': 662,
#  '“': 663,
#  '”': 664,
#  '._apple': 665,
#  '._sạc': 666,
#  '._thiết_bị': 667,
#  '15': 668,
#  '2018': 669,
#  '8169545261566': 670,
#  'a': 671,
#  'apple_thiết_kế': 672,
#  'barclays': 673,
#  'báo_cáo': 674,
#  'bảo_vệ': 675,
#  'bằng_sáng_chế': 676,
#  'chiếc': 677,
#  'chuyển_động': 678,
#  'chất_liệu': 679,
#  'công_bố': 680,
#  'công_ty': 681,
#  'dự_kiến': 682,
#  'dự_đoán': 683,
#  'dựa': 684,
#  'google': 685,
#  'gồm': 686,
#  'headphone': 687,
#  'hoàn_thiện': 688,
#  'hy_vọng': 689,
#  'hình_ảnh': 690,
#  'hạn_chế': 691,
#  'hằng': 692,
#  'học': 693,
#  'hứa_hẹn': 694,
#  'lưng': 695,
#  'lớp': 696,
#  'mrxj2': 697,
#  'mv7n2': 698,
#  'mấy': 699,
#  'mặt_kính': 700,
#  'mồ_hôi': 701,
#  'ngày': 702,
#  'nhà_táo': 703,
#  'nhân_tố': 704,
#  'nhét': 705,
#  'năm': 706,
#  'phân_tích': 707,
#  'phút': 708,
#  'phủ': 709,
#  'pixel': 710,
#  'qi_airpower': 711,
#  'quan_trọng': 712,
#  'ra_mắt': 713,
#  'sinh': 714,
#  'so': 715,
#  'sự_kiện': 716,
#  'tai_nạn': 717,
#  'thường': 718,
#  'thấm': 719,
#  'thế_hệ': 720,
#  'tiền_nhiệm': 721,
#  'true_wireless': 722,
#  'trải_nghiệm': 723,
#  'trắc': 724,
#  'tuyệt_vời': 725,
#  'tích_hợp': 726,
#  'tập_luyện': 727,
#  'tối_giản': 728,
#  'vật_lý': 729,
#  'về': 730,
#  'đeo': 731,
#  'điện': 732,
#  'đo': 733,
#  'đáng_giá': 734,
#  'đây': 735,
#  'đăng_ký': 736,
#  'đầu': 737,
#  'đầu_tiên': 738,
#  'đẹp_mắt': 739,
#  'đều': 740,
#  'đời': 741,
#  '._chiếc': 742,
#  '._dây': 743,
#  '._jack': 744,
#  '._nhờ': 745,
#  '._nút': 746,
#  '1.2': 747,
#  '16': 748,
#  '1822568351962': 749,
#  '3_size': 750,
#  '9': 751,
#  'bo_cong': 752,
#  'bản_thân': 753,
#  'bầu_dục': 754,
#  'bện': 755,
#  'c150si': 756,
#  'chiều_dài': 757,
#  'chân_thực': 758,
#  'chịu_nhiệt': 759,
#  'chọn': 760,
#  'có_công_suất': 761,
#  'công_nghệ_lọc': 762,
#  'dbspl': 763,
#  'driver': 764,
#  'dài': 765,
#  'dễ_chịu': 766,
#  'giai_điệu': 767,
#  'hiện_đại': 768,
#  'housing': 769,
#  'hầu_hết': 770,
#  'jbl': 771,
#  'jbl_c150si': 772,
#  'khz': 773,
#  'không_gian': 774,
#  'kiểu_dáng': 775,
#  'kèm': 776,
#  'kết_hợp_phần': 777,
#  'l': 778,
#  'lựa_chọn': 779,
#  'mang': 780,
#  'mic': 781,
#  'mw': 782,
#  'mềm_mại': 783,
#  'một_số': 784,
#  'nơi': 785,
#  'nổi_bật': 786,
#  'ohms': 787,
#  'pc': 788,
#  'phím': 789,
#  'qua_lại': 790,
#  'quản_lý': 791,
#  'rối': 792,
#  'rối_dây': 793,
#  'size': 794,
#  'smartphone': 795,
#  'sản_phẩm_giá': 796,
#  'tai_jbl_c150si': 797,
#  'thích_hợp': 798,
#  'thưởng_thức': 799,
#  'thị_trường': 800,
#  'thực_tế': 801,
#  'tiện_dụng': 802,
#  'trắng': 803,
#  'trọn_vẹn': 804,
#  'trở_kháng': 805,
#  'tương_đối': 806,
#  'tỉ_mỉ': 807,
#  'vật_liệu': 808,
#  'vặn': 809,
#  'xoắn': 810,
#  'yêu_thích': 811,
#  '±': 812,
#  '±_3.2': 813,
#  'êm_ái': 814,
#  'đen': 815,
#  'đàn_hồi': 816,
#  'đính': 817,
#  'đệm': 818,
#  'đỏ': 819,
#  '&': 820,
#  '._dual': 821,
#  '1.5': 822,
#  '12v': 823,
#  '154': 824,
#  '18w': 825,
#  '2.1': 826,
#  '2.4': 827,
#  '20.000': 828,
#  '20000': 829,
#  '27.3': 830,
#  '2a': 831,
#  '3.6': 832,
#  '4625882732076': 833,
#  '5.1': 834,
#  '5v': 835,
#  '73.6': 836,
#  '9v': 837,
#  'a_max': 838,
#  'a_output': 839,
#  'c': 840,
#  'dự_phòng': 841,
#  'in': 842,
#  'input': 843,
#  'micro-usb': 844,
#  'mạch': 845,
#  'nhỏ_giọt': 846,
#  'output': 847,
#  'pb200lmz': 848,
#  'pin_li-ion': 849,
#  'polymer': 850,
#  'port': 851,
#  'single': 852,
#  'type-c': 853,
#  'usb-a': 854,
#  'usb_type': 855,
#  'x': 856,
#  'xiaomi_redmi_20000': 857,
#  '._bạn': 858,
#  '._cấu_tạo': 859,
#  '._micro': 860,
#  '._phần': 861,
#  '._thiết_kế': 862,
#  '._được': 863,
#  '1.3': 864,
#  '22000': 865,
#  '8846209212804': 866,
#  '?_hãy': 867,
#  'bass': 868,
#  'byz': 869,
#  'byz_s389': 870,
#  'bông_tai': 871,
#  'bảng': 872,
#  'bất_cứ': 873,
#  'bất_kì': 874,
#  'bền_màu': 875,
#  'bố_trí': 876,
#  'bởi': 877,
#  'cao_su': 878,
#  'chiều': 879,
#  'chuyên_nghiệp': 880,
#  'chát': 881,
#  'cung_bậc': 882,
#  'cân_bằng': 883,
#  'cảm_xúc': 884,
#  'cực': 885,
#  'cực_nhanh': 886,
#  'diệu': 887,
#  'dây_cáp': 888,
#  'dòng': 889,
#  'giải': 890,
#  'gọn_gàng': 891,
#  'hiện_nay': 892,
#  'hoco_model_s389': 893,
#  'hong_kong_sku': 894,
#  'hài_hoà': 895,
#  'hài_hòa_._thân': 896,
#  'hòa': 897,
#  'hại': 898,
#  'ipad': 899,
#  'kỳ': 900,
#  'kỹ_thuật': 901,
#  'laptop': 902,
#  'lo': 903,
#  'làm_phiền': 904,
#  'lý_tưởng': 905,
#  'lọc': 906,
#  'mp3': 907,
#  'mp4': 908,
#  'muốn': 909,
#  'màng': 910,
#  'máy_tính': 911,
#  'mặc': 912,
#  'nhạc_phổ_biến': 913,
#  'nhựa_giá': 914,
#  'nào': 915,
#  'phút_giây': 916,
#  's389': 917,
#  'stereo': 918,
#  'super_bass': 919,
#  'thiết': 920,
#  'thông_qua': 921,
#  'thế_giới': 922,
#  'tinh_tế': 923,
#  'trang_phục': 924,
#  'trung': 925,
#  'truyền_tải': 926,
#  'trò_chuyện': 927,
#  'tái_hiện': 928,
#  'tín_đồ': 929,
#  'tạp_âm': 930,
#  'tần': 931,
#  'voice': 932,
#  'vừa': 933,
#  'âm_cao': 934,
#  'đâu': 935,
#  'đôi': 936,
#  'đặc_điểm': 937,
#  'độc_đáo': 938,
#  'ấm': 939,
#  '._cắm': 940,
#  '._giảm': 941,
#  '._kết_nối': 942,
#  '8756025930199': 943,
#  '90_%': 944,
#  'auto-sleep': 945,
#  'auto_sleep': 946,
#  'chrome_os': 947,
#  'chuột_m330': 948,
#  'chính_xác': 949,
#  'chắc_chắn': 950,
#  'chứng_nhận': 951,
#  'click': 952,
#  'con_trỏ': 953,
#  'cuộn': 954,
#  'công': 955,
#  'cạnh': 956,
#  'cầm': 957,
#  'cầm_nắm': 958,
#  'di': 959,
#  'dành': 960,
#  'dễ': 961,
#  'kiểm': 962,
#  'kêu': 963,
#  'linux': 964,
#  'linux_giá': 965,
#  'logitech': 966,
#  'logitech_m330_silent_plus': 967,
#  'mac': 968,
#  'rê': 969,
#  'sỹ': 970,
#  'thu': 971,
#  'thuận_tay_phải': 972,
#  'thái_học': 973,
#  'thụy': 974,
#  'trái': 975,
#  'tất_cả': 976,
#  'tắt': 977,
#  'viền': 978,
#  'windows': 979,
#  'xài': 980,
#  'yên_tâm': 981,
#  'yên_tĩnh': 982,
#  'đơn_vị': 983,
#  'đọc': 984,
#  'độc_lập': 985,
#  '10.5': 986,
#  '2.6': 987,
#  '6706802071227': 988,
#  '7_,_mac_os': 989,
#  'cm': 990,
#  'dài_lâu': 991,
#  'game': 992,
#  'kernel': 993,
#  'linux_kernel_2.6_sku': 994,
#  'logitech_b175': 995,
#  'lướt': 996,
#  'model_b175': 997,
#  'tha_hồ': 998,
#  'tầm': 999,
#  ...}

# %%
# Number of features (words) in dictionaries
feature_count = len(dictionary.token2id)

# %%
feature_count
# Out:
# 57970

# %%
# Obtain corpus based on dictionary (dense matrix)
corpus = [dictionary.doc2bow(text) for text in intro_products_re]

# %%
corpus[0]
# Out:
# [(0, 1),
#  (1, 3),
#  (2, 1),
#  (3, 2),
#  (4, 1),
#  (5, 3),
#  (6, 2),
#  (7, 4),
#  (8, 1),
#  (9, 2),
#  (10, 2),
#  (11, 1),
#  (12, 1),
#  (13, 1),
#  (14, 2),
#  (15, 3),
#  (16, 1),
#  (17, 1),
#  (18, 1),
#  (19, 1),
#  (20, 1),
#  (21, 4),
#  (22, 1),
#  (23, 1),
#  (24, 1),
#  (25, 1),
#  (26, 1),
#  (27, 3),
#  (28, 1),
#  (29, 1),
#  (30, 2),
#  (31, 1),
#  (32, 2),
#  (33, 1),
#  (34, 1),
#  (35, 1),
#  (36, 1),
#  (37, 1),
#  (38, 1),
#  (39, 1),
#  (40, 2),
#  (41, 1),
#  (42, 2),
#  (43, 1),
#  (44, 1),
#  (45, 1),
#  (46, 2),
#  (47, 1),
#  (48, 3),
#  (49, 1),
#  (50, 1),
#  (51, 1),
#  (52, 2),
#  (53, 1),
#  (54, 1),
#  (55, 1),
#  (56, 1),
#  (57, 1),
#  (58, 1),
#  (59, 2),
#  (60, 1),
#  (61, 3),
#  (62, 1),
#  (63, 3),
#  (64, 2),
#  (65, 1),
#  (66, 2),
#  (67, 2),
#  (68, 1),
#  (69, 1),
#  (70, 1),
#  (71, 1),
#  (72, 1),
#  (73, 1),
#  (74, 2),
#  (75, 1),
#  (76, 1),
#  (77, 3),
#  (78, 4),
#  (79, 1),
#  (80, 2),
#  (81, 4),
#  (82, 1),
#  (83, 3),
#  (84, 1),
#  (85, 1),
#  (86, 2),
#  (87, 1),
#  (88, 1),
#  (89, 1),
#  (90, 2),
#  (91, 1),
#  (92, 1),
#  (93, 1),
#  (94, 1),
#  (95, 1),
#  (96, 4),
#  (97, 1),
#  (98, 1),
#  (99, 1),
#  (100, 5),
#  (101, 3),
#  (102, 2),
#  (103, 1),
#  (104, 3),
#  (105, 3),
#  (106, 2),
#  (107, 1),
#  (108, 1),
#  (109, 1),
#  (110, 2),
#  (111, 1),
#  (112, 1),
#  (113, 1),
#  (114, 1),
#  (115, 1),
#  (116, 2),
#  (117, 9),
#  (118, 1),
#  (119, 1),
#  (120, 1),
#  (121, 1),
#  (122, 1),
#  (123, 2),
#  (124, 1),
#  (125, 1),
#  (126, 1),
#  (127, 1),
#  (128, 1),
#  (129, 1),
#  (130, 3),
#  (131, 4),
#  (132, 1),
#  (133, 1),
#  (134, 1),
#  (135, 1),
#  (136, 1),
#  (137, 2),
#  (138, 2),
#  (139, 2),
#  (140, 2),
#  (141, 1),
#  (142, 2),
#  (143, 1),
#  (144, 1),
#  (145, 1),
#  (146, 1),
#  (147, 1),
#  (148, 1),
#  (149, 2),
#  (150, 3),
#  (151, 1),
#  (152, 1),
#  (153, 1),
#  (154, 2)]

# %%
# Use TF-IDF Model to process corpus, obtaining index
tfidf = models.TfidfModel(corpus)
# tính toán sự tương tự trong ma trận thưa thớt
index = similarities.SparseMatrixSimilarity(tfidf[corpus],num_features=feature_count)

# %%
# When user choose one product: 1059892, 52333193
product_ID = 10001355
product = products[products.item_id == product_ID].head(1)

# %%
type(product['name_desciption_pre'])
# Out:
# pandas.core.series.Series

# %%
product[['item_id','name_desciption_pre']]
# Out:
#        item_id                                name_desciption_pre
# 2660  10001355  RAM Laptop_Hynix_4GB_DDR4_2400MH z SODIMM - Hà...

# %%
# View product
name_description_pre = product['name_desciption_pre'].to_string(index=False)

# %%
name_description_pre
# Out:
# 'RAM Laptop_Hynix_4GB_DDR4_2400MH z SODIMM - Hàn...'

# %%
# Suggest other products for customers
def recommendation (view_product, dictionary, tfidf, index):
    # Convert search words into Sparse Vectors
    view_product = view_product.lower().split()
    kw_vector = dictionary.doc2bow(view_product)
    print("View product 's vector:")
    print(kw_vector)
    # Similarity calculation
    sim = index[tfidf[kw_vector]]
    
    # print result
    list_id = []
    list_score = []
    for i in range(len(sim)):
        list_id.append(i)
        list_score.append(sim[i])
    
    df_result = pd.DataFrame({'id': list_id,
                              'score': list_score})
    
    # five highest scores
    five_highest_score = df_result.sort_values(by='score', ascending=False).head(6)
    print("Five highest scores:")
    print(five_highest_score)
    print("Ids to list:")
    idToList = list(five_highest_score['id'])
    print(idToList)
    
    products_find = products[products.index.isin(idToList)]
    results = products_find[['item_id','name']]
    results = pd.concat([results, five_highest_score], axis=1).sort_values(by='score', ascending=False)
    return results

# %%
results = recommendation(name_description_pre, dictionary, tfidf, index)
# Out:
# View product 's vector:
# [(483, 1), (495, 1), (28985, 1), (38434, 1)]
# Five highest scores:
#         id     score
# 2658  2658  0.596752
# 2314  2314  0.263400
# 2505  2505  0.256717
# 2473  2473  0.251999
# 2413  2413  0.250081
# 2662  2662  0.239666
# Ids to list:
# [2658, 2314, 2505, 2473, 2413, 2662]

# %%
# Recommender 5 similarities products for the selected product
# Check and remove the selected product from the results
results = results[results.item_id!=product_ID]
results
# Out:
#        item_id                                               name    id  \
# 2658  57316596  Màn hình AOC 27G2 (27 inch/FHD/IPS/144Hz/1ms/G...  2658
# 2314  58677681      N200RE_V5 - Mini Router Wi-Fi chuẩn N 300Mbps  2314
# 2505    576880  Màn Hình Gaming Cong Samsung LC27F390FHEXXV 27...  2505
# 2473   7975728        Chuột máy tính Newmen G10 - Hàng Chính Hãng  2473
# 2413  14606621  Keo Tản Nhiệt ARCTIC MX4 - 4g  (2020) - Hàng C...  2413
# 2662  68308394  Card WIFI PC WIFI-6 AX200 GIG+ tích hợp Blueto...  2662
#
#          score
# 2658  0.596752
# 2314  0.263400
# 2505  0.256717
# 2473  0.251999
# 2413  0.250081
# 2662  0.239666

# %% [markdown]
# ### Save results

# %%
dictionary.save("Gensim_Model.sav")

# %%
dictionary.load("Gensim_Model.sav")
